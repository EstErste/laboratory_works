# %%
pip install pytesseract

# %%
import pytesseract 
import cv2
pytesseract.pytesseract.tesseract_cmd = r"C:/Tesseract-OCR/tesseract.exe"

# %%
imagetxt = cv2.imread('./image/text1.jpg')
text = pytesseract.image_to_string(imagetxt, lang='rus')
print(text)

# %%
cv2.imshow('Input image', imagetxt)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#разобраться почему его так кроет в чем проблема
cap = cv2.VideoCapture('./image/video-text.mp4')

c = list("“‘'(){}[]?/|-_*+!@#№$%^&=;:1234567890~»«.,’""¥—”¢”°><®") 

while True:
  success, img = cap.read()  
  
  text = pytesseract.image_to_string(img, lang='eng')
  
  for i in range(0, len(c)-1):  
    text = text.replace(c[i],"") 

  print(text)

  if cv2.waitKey(1) & 0xFF == ord ('q'):  
    break
# Out:
# story"
#
# yS a ME
#
# Seem So yu sues
# a eR a
# BAe A Lo
#
#
#
# os
# ao
#
# a
#
# S
#
#
#
# YS
#
# Mi
#
#
# story"
#
#  La my f v
# Setar nal Mp Prins sae
#
# Wry ees i sik
#
# AAW  y   f
#
# x
#
#
#
# ee
# Bo
#  PF
# S
#
#
# heresal
# et i
# vet
#
#
#
# ai
#
# o
# a
#
# VS
#
#
# story"
#
# J a d
# Poe ae eH age
#  ORS teen
#  ay
# wy ve  x y
# Weary
#
# x
#
#
#
# Wwaysa
#
# heresal
# et i
# Pre
#
#
#
# ai
#
# a
# a
#
# VS
#
# story"
#
#   J
# Pe ae EN ag"
#  Rohrer
#   \\  f
# wy ve  x y
# ar Oe
#
# x
#
# waysa
#
# mt
#
#
#
# heres al
#
#
#
# oF ah
#
# eS Bang
# a
#
# Me
#
# ye
#
# story"
#
#   J
# Pe ae EN Wag"
#  Rot Rer es
#   \\  f
# wy We  x y
# Nie lt
#
# x
#
# waysa
#
# mt
#
#
#
# heres al
#
#
#
# oF ah
#
# eS Bang
# o
#
# Me
#
# ye
#
# a a k
# Pet ae ee ON
# rx \ vais RF sf
# ak Soy Be WS
# Kin die
#
# x
#
#
#
# ways a
#
# eres al
# r
#
# Ea
# a
#
# Th
#
# oy
# hit
# bo
#
# Mi
#
#
#  ee
#
#
# i
#
#
# A
#
# e me hs
# F
#
# Se
#
# Ae
#
# a
#
# fe Ay
# os
#
# \
#
# x
#
# \
# ...

# %%
import cv2
cap = cv2.VideoCapture('./image/video-text.mp4')

c = list("“‘'(){}[]?/|-_*+!@#№$%^&=;:1234567890~»«.,’""¥—”¢”°><®") 

if not cap.isOpened():
    print('error: could not open video.')
    exit()

fps = cap.get(cv2.CAP_PROP_FPS) #получаем количество кадров в секунду
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) #общее количество кадров в видео
duration = frame_count / fps #продолжительность видео в секундах

while cap.isOpened():
    ret, frame = cap.read()
    
    if not ret:
        break

    
  
    for i in range(0, len(c)-1):  
        text = text.replace(c[i],"") 

    print(text)

    #ожидание 25 млсекунд между кадрами для видео с частотой 40 fps(1/40 секунды = 40 кадров в секунду)
    if cv2.waitKey(int(1000/fps)) & 0xFF == ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 20
#      17 if not ret:
#      18     break
# ---> 20 text = pytesseract.image_to_string(img, lang='eng')
#      22 for i in range(0, len(c)-1):
#      23     text = text.replace(c[i],"")
#
# File c:\Users\ester\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytesseract\pytesseract.py:486, in image_to_string(image, lang, config, nice, output_type, timeout)
#     481 """
#     482 Returns the result of a Tesseract OCR run on the provided image to string
#     483 """
#     484 args = [image, 'txt', lang, config, nice, timeout]
# --> 486 return {
#     487     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     489     Output.STRING: lambda: run_and_get_output(*args),
#     490 }[output_type]()
#
# ...
